# %%
from dijkstra import Graph

# %%
from IPython.display import Image

# %%
Image("./graph_example.png")

# %%
G = Graph([['A','B',8],
           ['A','C',2],
           ['A','D',5],
           ['B','D',2],
           ['B','F',13],
           ['C','D',2],
           ['C','E',5],
           ['D','F',6],
           ['D','E',1],
           ['D','G',3],
           ['E','G',1],
           ['G','F',2],
           ['G','H',6],
           ['F','H',3]])

# %%
G.genNodesById()

# %%
G.setNeighbors()

# %%
G.dijkstra('A')
# Out:
# C 2 ['A']
# D 4 ['C', 'A']
# E 5 ['D', 'C', 'A']
# B 6 ['D', 'C', 'A']
# G 6 ['E', 'D', 'C', 'A']
# F 8 ['G', 'E', 'D', 'C', 'A']
# H 11 ['F', 'G', 'E', 'D', 'C', 'A']
